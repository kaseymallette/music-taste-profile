# %% [markdown]
# # Exploratory Analysis
#
# **Purpose:** Explore descriptive stats and features

# %% [markdown]
# ## Import Libraries

# %%
# Import necessary libraries for data analysis and visualization
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# ## Read and Clean Data

# %%
# Read data from CSV files to create genre playlists dataframe
df_rock = pd.read_csv('../data/spotify/rock.csv')
df_alternative = pd.read_csv('../data/spotify/alternative.csv')
df_pop = pd.read_csv('../data/spotify/pop.csv')
df_rap_rnb = pd.read_csv('../data/spotify/rap_rnb.csv')
df_liked_songs = pd.read_csv('../data/spotify/liked_songs.csv')

# Add playlist column to each dataset
df_rock['Playlist'] = 'Rock'
df_alternative['Playlist'] = 'Alternative'
df_pop['Playlist'] = 'Pop'
df_rap_rnb['Playlist'] = 'Rap RnB'
df_liked_songs['Playlist'] = 'Liked Songs'

# Create a playlist of the genres 
df_genres = pd.concat([df_rock, df_alternative, df_pop, df_rap_rnb]
                       ).drop_duplicates(['Song', 'Artist'], keep='first'
                       ).reset_index(drop=True).drop(columns=['#']
                       ).sort_values(by=['Song', 'Artist'], ignore_index=True)

# Normalize song and artist names for accurate merging
df_liked_songs['Song_lower'] = df_liked_songs['Song'].str.lower().str.strip()
df_liked_songs['Artist_lower'] = df_liked_songs['Artist'].str.lower().str.strip()
df_genres['Song_lower'] = df_genres['Song'].str.lower().str.strip()
df_genres['Artist_lower'] = df_genres['Artist'].str.lower().str.strip()

# Drop duplicates in df_liked_songs
df_liked_songs_unique = df_liked_songs.drop_duplicates(subset=['Song_lower', 'Artist_lower'], keep='first').reset_index(drop=True)

print(len(df_genres), "total songs in combined genre playlists")
print(len(df_liked_songs), "total songs in liked songs playlist")
print(f'\n{len(df_liked_songs) - len(df_liked_songs_unique)}', "duplicate songs in liked songs playlist")
print(len(df_liked_songs_unique), "unique songs in liked songs playlist")
# Out:
# 1000 total songs in combined genre playlists
# 2000 total songs in liked songs playlist
#
# 36 duplicate songs in liked songs playlist
# 1964 unique songs in liked songs playlist

# %%
# Create a playlist of liked songs not in the genre playlists
df_merged = df_liked_songs.merge(
    df_genres[['Song_lower', 'Artist_lower']].drop_duplicates(),
    on=['Song_lower', 'Artist_lower'],
    how='left',
    indicator=True
)

# Filter and dedupe on normalized keys, keep original casing
df_not_in_genre = (
    df_merged[df_merged['_merge'] == 'left_only']
    .drop_duplicates(subset=['Song_lower', 'Artist_lower'], keep='first')
    .drop(columns=['_merge', '#', 'Song_lower', 'Artist_lower'])
    .sort_values(by=['Song', 'Artist'])
    .reset_index(drop=True)
)

# Drop the normalized keys from df_genres as well
df_genres = df_genres.drop(columns=['Song_lower', 'Artist_lower'])

# Merge genre playlists with liked songs
df_library = (
    pd.concat([df_genres, df_not_in_genre], ignore_index=True)
    .sort_values(by=['Song', 'Artist'])
    .reset_index(drop=True)
)

# Add album year from 'Album Date' column and create a new column 'Album Year' as year
df_library['Album Year'] = df_library['Album Date'].str[:4].astype(int)

# Save to csv for future use
df_library.to_csv('../data/music_library.csv', index=False)

# Print length of final library and display 
print(len(df_library), "total songs in final music library")
df_library
# Out:
# 2309 total songs in final music library
#                                                 Song              Artist  BPM  \
# 0                                                 #1               Nelly  180
# 1                                                #88             Lo-Fang  135
# 2                                               &Run             Sir Sly   92
# 3               (I Can't Get No) Satisfaction - Mono  The Rolling Stones  136
# 4     (If You're Not In It For Love) I'm Outta Here!        Shania Twain  120
# ...                                              ...                 ...  ...
# 2304                                      wet dreams             Artemas  126
# 2305                               wish you were gay       Billie Eilish  118
# 2306                    you should see me in a crown       Billie Eilish  150
# 2307                          you've been a bad girl             Artemas  137
# 2308                                           youth         cleopatrick   95
#
#      Camelot  Energy    Added At Duration  Popularity              Genres  \
# 0         9B      59  2026-03-10    03:18          57                 NaN
# 1         9B      34  2026-03-16    05:48           0                 NaN
# 2         7B      66  2026-03-02    03:46          61                 NaN
# 3        10B      86  2026-03-16    03:42          74  classic rock, rock
# 4         7B      76  2026-03-11    04:30          54             country
# ...      ...     ...         ...      ...         ...                 ...
# 2304      9B      72  2026-04-05    01:39          69                 NaN
# 2305      9B      35  2026-04-05    03:41          75                 NaN
# 2306     12B      53  2026-03-02    03:00          77                 NaN
# 2307      9A      87  2026-03-30    02:23          61                 NaN
# 2308      6A      83  2026-03-05    04:03          46                 NaN
#
#                                          Album  ... Valence  Speech  Live  \
# 0                                   Nellyville  ...      46      30    50
# 1                                          #88  ...      40       0     0
# 2                       Don't You Worry, Honey  ...      48       0    10
# 3                             Out Of Our Heads  ...      93       0    10
# 4                              The Woman In Me  ...      87       0     0
# ...                                        ...  ...     ...     ...   ...
# 2304                                   yustyna  ...       4       0    20
# 2305  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?  ...      28      20    70
# 2306  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?  ...      32      10    10
# 2307                                   yustyna  ...      37       0    10
# 2308                                     youth  ...      39       0    50
#
#       Loud (Db)      Key  Time Signature        Spotify Track Id  \
# 0            -6  G Major               4  7rSj5gEdN5KgHwbnEVAZ4b
# 1           -10  G Major               4  1jjwFHRnfgBTJ049RJz8CQ
# 2            -8  F Major               4  0w4m3Xp4svlIoyL94Zjlyd
# 3            -8  D Major               4  2PzU4IB8Dr6mxV3lHuaG34
# 4            -8  F Major               4  6Lst3nF4McKOTLSLuTvLhw
# ...         ...      ...             ...                     ...
# 2304         -6  G Major               4  6Q57LMIIjmbOBkvXe8ADW4
# 2305        -10  G Major               4  3Fj47GNK2kUF0uaEDgXLaD
# 2306        -10  E Major               4  3XF5xLJHOQQRbWya6hBp7d
# 2307         -2  E Minor               4  6Gron8VFcNPwj7ZamJe7Pt
# 2308         -4  G Minor               4  2zHetDvbVhumY7pmAPOdnX
#
#               ISRC     Playlist  Album Year
# 0     USUR10200366      Rap RnB        2002
# 1     GBAFL2000240  Alternative        2013
# 2     USUM71704895  Liked Songs        2017
# 3     USA176510160         Rock        1965
# 4     USPR39402724          Pop        1995
# ...            ...          ...         ...
# 2304  QZJ842401770  Liked Songs        2024
# 2305  USUM71900767  Liked Songs        2019
# 2306  USUM71810049  Liked Songs        2019
# 2307  QZJ842401766  Liked Songs        2024
# 2308  CAI371713382         Rock        2018
#
# [2309 rows x 24 columns]

# %% [markdown]
# ## Explore Data

# %% [markdown]
# ### Songs by Playlist

# %%
songs_by_playlist = df_library.groupby('Playlist').size().reset_index(name='Count')
print(songs_by_playlist)
# Out:
#       Playlist  Count
# 0  Alternative    250
# 1  Liked Songs   1309
# 2          Pop    250
# 3      Rap RnB    250
# 4         Rock    250

# %% [markdown]
# ### Songs by Artists

# %%
# Count the number of songs by each artist in the library
df_artists = df_library['Artist'].value_counts().reset_index()
df_artists.columns = ['Artist', 'Count']

# Group by playlist and artist to count the number of songs by each artist in each playlist
df_artists_by_playlist = df_library.groupby(['Playlist', 'Artist']).size().reset_index(name='Count')

# Count the number of unique artists in each playlist
unique_artists_by_playlist = df_library.groupby('Playlist')['Artist'].nunique().reset_index(name='Unique Artists')

# Print number of artists
print(f"Number of unique artists in the library: {len(df_artists)}")

# Print number of unique artists by playlist
print("\nNumber of unique artists by playlist:")
for index, row in unique_artists_by_playlist.iterrows():
    print(f"  {row['Playlist']}: {row['Unique Artists']}") 

# Return df_artists
df_artists
# Out:
# Number of unique artists in the library: 1046
#
# Number of unique artists by playlist:
#   Alternative: 152
#   Liked Songs: 618
#   Pop: 141
#   Rap RnB: 182
#   Rock: 144
#                       Artist  Count
# 0                     Eminem     20
# 1          The Neighbourhood     20
# 2                Matt Maeson     20
# 3     Florence + The Machine     20
# 4                   Maroon 5     18
# ...                      ...    ...
# 1041   Post Malone,21 Savage      1
# 1042                YUNGBLUD      1
# 1043                     dye      1
# 1044        Christian French      1
# 1045            Ella Langley      1
#
# [1046 rows x 2 columns]

# %%
def plot_artist_distribution(df, playlist=None, bin_max=9, ax=None):
    """
    Plot distribution of song counts per artist.
    
    Args:
        df: DataFrame with artist counts (must have 'Count' column)
        playlist: If provided, filter to this playlist (requires 'Playlist' column)
        bin_max: Counts above this are binned as '{bin_max+1}+'
        ax: Matplotlib axes to plot on (creates new figure if None)
    """
    # Filter if playlist specified
    if playlist:
        df = df[df['Playlist'] == playlist]
        title = playlist
    else:
        title = 'Distribution of Song Count by Artist'
    
    # Bin the counts
    def bin_count(x):
        return str(x) if x <= bin_max else f'{bin_max + 1}+'
    
    bin_order = [str(i) for i in range(1, bin_max + 1)] + [f'{bin_max + 1}+']
    bins = df['Count'].apply(bin_count)
    freq = bins.value_counts().reindex(bin_order, fill_value=0)
    
    # Plot
    if ax is None:
        fig, ax = plt.subplots(figsize=(10, 5))
        standalone = True
    else:
        standalone = False
    
    ax.bar(freq.index, freq.values, color='steelblue', edgecolor='white')
    ax.set_xlabel('Number of Songs')
    ax.set_ylabel('Number of Artists')
    ax.set_title(title)
    
    if standalone:
        plt.tight_layout()
        plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 10))
playlists = ['Rock', 'Alternative', 'Pop', 'Rap RnB', 'Liked Songs']

for ax, playlist in zip(axes.flatten(), playlists):
    plot_artist_distribution(df_artists_by_playlist, playlist=playlist, ax=ax)

fig.suptitle('Distribution of Song Count by Artist by Playlist', fontsize=14)
axes.flatten()[5].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Album Year

# %%
# Bin album release years into decades
def bin_decade(year):
    if pd.isna(year):
        return 'Unknown'
    year = int(year)
    if year < 1970:
        return '1960s'
    elif year < 1980:
        return '1970s'
    elif year < 1990:
        return '1980s'
    elif year < 2000:
        return '1990s'
    elif year < 2010:
        return '2000s'
    elif year < 2020:
        return '2010s'
    else:
        return '2020s'

decade_order = ['1960s', '1970s', '1980s', '1990s', '2000s', '2010s', '2020s', 'Unknown']

df_library['Decade'] = df_library['Album Year'].apply(bin_decade)
decade_counts = df_library['Decade'].value_counts().reindex(decade_order, fill_value=0)
decade_counts
# Out:
# Decade
# 1960s       14
# 1970s       52
# 1980s       90
# 1990s      137
# 2000s      654
# 2010s      904
# 2020s      458
# Unknown      0
# Name: count, dtype: int64

# %%
# Get decade counts by playlist
decade_counts_by_playlist = (
    df_library.groupby(['Playlist', 'Decade'])
    .size()
    .reindex(pd.MultiIndex.from_product([['Alternative', 'Pop', 'Rap RnB', 'Rock', 'Liked Songs'], decade_order], names=['Playlist', 'Decade']), fill_value=0)
    .reset_index(name='Count')
)

# Pivot dataframe
decade_pivot = decade_counts_by_playlist.pivot(index='Playlist', columns='Decade', values='Count')
decade_pivot.loc['Total'] = decade_pivot.sum()
decade_pivot
# Out:
# Decade       1960s  1970s  1980s  1990s  2000s  2010s  2020s  Unknown
# Playlist
# Alternative      0      0      0      0      0    190     60        0
# Liked Songs      9     15     26     50    356    520    333        0
# Pop              1      4     19     43    121     44     18        0
# Rap RnB          0      0      5     25    110     84     26        0
# Rock             4     33     40     19     67     66     21        0
# Total           14     52     90    137    654    904    458        0

# %%
decade_order_plot = ['1960s', '1970s', '1980s', '1990s', '2000s', '2010s', '2020s']

plot_data = decade_pivot.loc[['Rock', 'Alternative', 'Pop', 'Rap RnB'], decade_order_plot].copy()
plot_data = plot_data.loc[['Rock', 'Alternative', 'Pop', 'Rap RnB'], decade_order_plot]

plot_data.T.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.xlabel('Decade')
plt.ylabel('Number of Songs')
plt.title('Song Count by Decade: Rock vs Alternative vs Pop vs Rap RnB')
plt.legend(title='Playlist', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
decade_order_plot = ['1960s', '1970s', '1980s', '1990s', '2000s', '2010s', '2020s']

plot_data = decade_pivot.loc[['Liked Songs'], decade_order_plot].copy()
plot_data = plot_data.loc[['Liked Songs'], decade_order_plot]

plot_data.T.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.xlabel('Decade')
plt.ylabel('Number of Songs')
plt.title('Song Count by Decade: Liked Songs')
plt.legend(title='Playlist', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Analyze songs from 1995-2005 (CD era)
df_cds = df_library[(df_library['Album Year'] >= 1995) & (df_library['Album Year'] < 2006)]
print(f"Number of songs from 1995-2005: {len(df_cds)}")
print('Average number of songs per year in 1995-2005:', round(len(df_cds) / 11, 1))
print('Range of songs per year:', df_cds['Album Year'].value_counts().min(), '-', df_cds['Album Year'].value_counts().max())

# Analyze songs from 2006-2014 (iTunes era)
df_itunes = df_library[(df_library['Album Year'] >= 2006) & (df_library['Album Year'] < 2015)]
print(f"\nNumber of songs from 2006-2014: {len(df_itunes)}")
print('Average number of songs per year in 2006-2014:', round(len(df_itunes) / 9, 1))
print('Range of songs per year:', df_itunes['Album Year'].value_counts().min(), '-', df_itunes['Album Year'].value_counts().max())

# Analyze songs from 2015-2025 (Spotify era)
df_spotify = df_library[(df_library['Album Year'] >= 2015) & (df_library['Album Year'] < 2026)]
print(f"\nNumber of songs from 2015-2025: {len(df_spotify)}")
print('Average number of songs per year in 2020s:', round(len(df_spotify) / 11, 1))
print('Range of songs per year:', df_spotify['Album Year'].value_counts().min(), '-', df_spotify['Album Year'].value_counts().max())
# Out:
# Number of songs from 1995-2005: 426
# Average number of songs per year in 1995-2005: 38.7
# Range of songs per year: 10 - 74
#
# Number of songs from 2006-2014: 701
# Average number of songs per year in 2006-2014: 77.9
# Range of songs per year: 62 - 94
#
# Number of songs from 2015-2025: 942
# Average number of songs per year in 2020s: 85.6
# Range of songs per year: 43 - 123

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

eras = [
    (df_cds, range(1995, 2006), 'Songs by Release Year: CD Era (1995-2005)', 'steelblue'),
    (df_itunes, range(2006, 2015), 'Songs by Release Year: iTunes Era (2006-2014)', 'darkorange'),
    (df_spotify, range(2015, 2026), 'Songs by Release Year: Spotify Era (2015-2025)', 'seagreen'),
]

for ax, (df, xticks, title, color) in zip(axes, eras):
    ax.hist(df['Album Year'], bins=len(xticks), color=color, edgecolor='white')
    ax.set_xlabel('Year')
    ax.set_ylabel('Number of Songs')
    ax.set_title(title)
    ax.set_xticks(xticks)
    ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Popularity

# %%
df_library['Popularity'].describe()
# Out:
# count    2309.000000
# mean       55.614552
# std        20.415177
# min         0.000000
# 25%        43.000000
# 50%        59.000000
# 75%        71.000000
# max        98.000000
# Name: Popularity, dtype: float64

# %%
for playlist in df_library['Playlist'].unique():
    df_playlist = df_library[df_library['Playlist'] == playlist]
    sns.kdeplot(df_playlist['Popularity'], label=playlist, clip=(0, 100))

plt.xlabel('Popularity')
plt.ylabel('Density')
plt.title('Song Popularity Distribution by Playlist')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature Selection

# %%
METADATA = ['Song', 'Artist', 'Album', 'Playlist']
X = ['BPM', 'Valence', 'Dance', 'Energy', 'Acoustic', 'Loud (Db)', 'Speech', 'Live', 'Time Signature', 'Album Year', 'Popularity']

df_metadata = df_library[METADATA]
df_X = df_library[X]

print(df_X.describe())
# Out:
#                BPM      Valence        Dance       Energy     Acoustic  \
# count  2309.000000  2309.000000  2309.000000  2309.000000  2309.000000
# mean    122.060199    49.531399    61.813339    68.558683    15.338242
# std      28.343054    23.042939    15.110806    17.167304    20.890476
# min      60.000000     4.000000    12.000000     9.000000     0.000000
# 25%     100.000000    31.000000    52.000000    57.000000     1.000000
# 50%     120.000000    48.000000    62.000000    71.000000     6.000000
# 75%     140.000000    67.000000    73.000000    82.000000    21.000000
# max     218.000000    98.000000    99.000000    99.000000    95.000000
#
#          Loud (Db)       Speech         Live  Time Signature   Album Year  \
# count  2309.000000  2309.000000  2309.000000     2309.000000  2309.000000
# mean     -6.481594     3.490689    13.482027        3.975314  2010.302728
# std       2.590684     8.063468    14.273336        0.227633    11.563879
# min     -30.000000     0.000000     0.000000        1.000000  1955.000000
# 25%      -8.000000     0.000000     0.000000        4.000000  2005.000000
# 50%      -6.000000     0.000000    10.000000        4.000000  2013.000000
# 75%      -5.000000     0.000000    20.000000        4.000000  2018.000000
# max      -1.000000    90.000000    90.000000        5.000000  2026.000000
#
#         Popularity
# count  2309.000000
# mean     55.614552
# std      20.415177
# min       0.000000
# 25%      43.000000
# 50%      59.000000
# 75%      71.000000
# max      98.000000

# %%
def plot_feature_distributions(df_features, figsize=(14, 10)):
    """
    Plot histogram + KDE for each feature in the dataframe.
    
    Args:
        df_features: DataFrame with numeric features to plot
        figsize: Tuple for figure size (width, height)
    """
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    features = df_features.columns.tolist()
    n_features = len(features)
    
    # Calculate grid dimensions
    n_cols = 3
    n_rows = (n_features + n_cols - 1) // n_cols
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=figsize)
    axes = axes.flatten()
    
    for i, feature in enumerate(features):
        ax = axes[i]
        
        # Histogram with KDE overlay
        sns.histplot(df_features[feature], kde=True, ax=ax, color='steelblue', 
                     edgecolor='white', alpha=0.7)
        
        # Add summary stats as text
        mean = df_features[feature].mean()
        median = df_features[feature].median()
        std = df_features[feature].std()
        
        stats_text = f'μ={mean:.1f}  med={median:.1f}  σ={std:.1f}'
        ax.set_title(f'{feature}\n{stats_text}', fontsize=10)
        ax.set_xlabel('')
        ax.set_ylabel('')
    
    # Turn off unused subplots
    for j in range(i + 1, len(axes)):
        axes[j].axis('off')
    
    plt.suptitle('Feature Distributions', fontsize=14, y=1.02)
    plt.tight_layout()
    plt.show()

# %%
plot_feature_distributions(df_X)

# %%
# Drop 'Speech', 'Live', 'Time Signature' from features based on EDA insights
FEATURES = ['BPM', 'Valence', 'Dance', 'Energy', 'Acoustic', 'Loud (Db)', 'Album Year', 'Popularity']
df_features = df_library[FEATURES]

# %%
# Calculate and plot correlation matrix for features
df_features_corr = df_features.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(df_features_corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Audio Features')
plt.tight_layout()
plt.show()

# %%
# Run PCA and plot variance explained to determine how many components to keep for clustering
def explore_pca(df_features):
    """Fit PCA on all components, plot variance explained, return scaler + pca."""
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(df_features)

    pca = PCA()
    pca.fit(X_scaled)
    var_explained = pca.explained_variance_ratio_
    cumulative = var_explained.cumsum()

    fig, ax = plt.subplots(figsize=(8, 5))
    x_pos = range(1, len(var_explained) + 1)
    ax.bar(x_pos, var_explained, alpha=0.7, label='Individual')
    ax.plot(x_pos, cumulative, 'ro-', label='Cumulative')
    ax.set_xticks(x_pos)
    ax.set_xticklabels([f'PC{i}' for i in x_pos])
    ax.set_ylabel('Variance Explained')
    ax.set_xlabel('Principal Component')
    ax.axhline(y=0.9, color='gray', linestyle='--', alpha=0.5, label='90% threshold')
    ax.legend()
    ax.set_ylim(0, 1.05)
    plt.title('PCA Variance Explained')
    plt.tight_layout()
    plt.show()

    print("=" * 50)
    print("VARIANCE EXPLAINED")
    print("=" * 50)
    for i, (var, cum) in enumerate(zip(var_explained, cumulative)):
        print(f"PC{i+1}: {var:.1%} (cumulative: {cum:.1%})")

    return {
        'scaler': scaler,
        'pca': pca,
        'var_explained': var_explained,
        'cumulative': cumulative, 
        'X_scaled': X_scaled 
    }

# %%
pca_results = explore_pca(df_features)
# Out:
# ==================================================
# VARIANCE EXPLAINED
# ==================================================
# PC1: 28.0% (cumulative: 28.0%)
# PC2: 18.5% (cumulative: 46.5%)
# PC3: 15.5% (cumulative: 62.0%)
# PC4: 11.7% (cumulative: 73.7%)
# PC5: 10.5% (cumulative: 84.2%)
# PC6: 7.5% (cumulative: 91.7%)
# PC7: 5.2% (cumulative: 96.9%)
# PC8: 3.1% (cumulative: 100.0%)
