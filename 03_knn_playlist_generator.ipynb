# %% [markdown]
# # KNN Playlist Generator
# **Purpose:** Given a playlist and n seed songs, generate a playlist using nearest neighbors.
#
# **Features:** BPM, Valence, Dance, Energy, Acoustic, Year, Popularity
#
# **Steps:**
# 1. Select seed songs and map the feature space using K-means clustering and PCA.
# 2. Pick k-nearest neighbors for each seed song to generate a playlist.

# %% [markdown]
# ## Import Libraries

# %%
# Import necessary libraries for data analysis and visualization
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

# %% [markdown]
# ## Read Data

# %%
df_playlist = pd.read_csv('data/music_library.csv')
df_playlist
# Out:
#        #                                  Song                     Artist  \
# 0      1                 When the Love is Gone                   Des Rocs
# 1      2                          BURNER PHONE                cleopatrick
# 2      3                       Queen Of Spades                       Styx
# 3      4                       Go Your Own Way              Fleetwood Mac
# 4      5  I Don't Care Anymore - 2016 Remaster               Phil Collins
# ..   ...                                   ...                        ...
# 995  246                           Not Like Us             Kendrick Lamar
# 996  247                         THANK GODDESS                Qveen Herby
# 997  248         STUPID (feat. Yung Baby Tate)         Ashnikko,Baby Tate
# 998  249                                HAHAHA                  Lil Dicky
# 999  250    Danny Phantom (feat. XXXTENTACION)  Trippie Redd,XXXTENTACION
#
#      BPM Camelot  Energy    Added At Duration  Popularity  \
# 0    141      9A      81  2026-03-05    03:20          52
# 1    136      9A      91  2026-03-05    03:21          42
# 2    135     12A      45  2026-03-05    05:41          36
# 3    136      7B      81  2026-03-05    03:38          62
# 4    140      1B      42  2026-03-05    05:05          61
# ..   ...     ...     ...         ...      ...         ...
# 995  101      3B      47  2026-03-10    04:34          88
# 996  106      8A      74  2026-03-11    02:47          52
# 997  150     10B      64  2026-03-11    02:47          65
# 998  158      3B      49  2026-03-11    04:03          41
# 999  147     10A      80  2026-03-16    02:16          51
#
#                                   Genres  ... Valence Speech  Live  Loud (Db)  \
# 0                                    NaN  ...      47      0    20         -4
# 1                                    NaN  ...      46      0    30         -5
# 2    classic rock, aor, progressive rock  ...      12      0    10        -13
# 3    yacht rock, classic rock, soft rock  ...      82      0    10        -12
# 4                              soft rock  ...      44      0     0         -8
# ..                                   ...  ...     ...    ...   ...        ...
# 995          hip hop, west coast hip hop  ...      21      0    10         -7
# 996                                  NaN  ...      38     10     0         -5
# 997                                  NaN  ...      54     10     0         -7
# 998                                  NaN  ...      14     10    10         -7
# 999                 melodic rap, emo rap  ...      81     40    30         -7
#
#              Key  Time Signature        Spotify Track Id          ISRC  \
# 0        E Minor               4  5iRv1aH4eNai45KfhjtJ6n  USFYZ2557602
# 1        E Minor               4  1nUC2uuKUl49tDwQ1m4A1J  CAJXF2500023
# 2    C♯/D♭ Minor               4  54g63GAn77x9NcjiLzy7cW  USAM17802305
# 3        F Major               4  15rjQH7nTcTomKwfVMd4xl  USWB19900181
# 4        B Major               4  24IdPCimVnJJDRuB5YSDiS  USRH11509311
# ..           ...             ...                     ...           ...
# 995  C♯/D♭ Major               4  6AI3ezQ4o3HUoP6Dhudph3  USUG12400910
# 996      A Minor               4  27IubiEgQJczAE6OC7PgmQ  QZFZ62344251
# 997      D Major               4  6qNB2ChCVPepl5ZjVJJTUW  GBAYE1900593
# 998  C♯/D♭ Major               4  73cnzXHK8i4WC5Pw0ZIZ2F  QMRSZ2302742
# 999      B Minor               4  2CxXnPvHjWOrzSVvNs0j8c  QZJ842001150
#
#      Playlist Album Year
# 0        Rock       2026
# 1        Rock       2025
# 2        Rock       1978
# 3        Rock       1988
# 4        Rock       1982
# ..        ...        ...
# 995   Rap-R&B       2024
# 996   Rap-R&B       2023
# 997   Rap-R&B       2019
# 998   Rap-R&B       2024
# 999   Rap-R&B       2021
#
# [1000 rows x 25 columns]

# %% [markdown]
# ## Environment Variables

# %%
# === CONFIG ===
FEATURES = ['BPM', 'Dance', 'Energy', 'Valence', 'Acoustic']
METADATA = ['Song', 'Artist', 'Album', 'Playlist', 'Popularity', 'Album Date']

# Extract album year on the main df first
df_playlist['Album Year'] = df_playlist['Album Date'].str[:4].astype(int)

# Then slice
df_playlist_features = df_playlist[FEATURES]
df_playlist_metadata = df_playlist[METADATA + ['Album Year']]

# Verify
print(f"Songs: {len(df_playlist)}")
print(f"Features: {FEATURES}")
print(f"Missing features: {df_playlist[FEATURES].isna().sum().sum()}")
print(f"Missing album year: {df_playlist['Album Year'].isna().sum()}")
# Out:
# Songs: 1000
# Features: ['BPM', 'Dance', 'Energy', 'Valence', 'Acoustic']
# Missing features: 0
# Missing album year: 0

# %% [markdown]
# ## Generate Playlist

# %% [markdown]
# ### 1. Select Seed Songs and Map Space

# %%
## == HELPER FUNCTIONS ===

# Collect seed songs into a DataFrame
def collect_seeds(df_playlist_metadata, df_playlist_features, seed_songs_dict):
    """
    Collect seed song data into a DataFrame.
    
    Parameters:
    - seed_songs_dict: dict of {song_name: artist_name}
    
    Returns:
    - df_seeds: DataFrame with song, artist, popularity, year, and FEATURES
    """
    seeds = []
    for song, artist in seed_songs_dict.items():
        result = get_song_features(df_playlist_metadata, df_playlist_features, song, artist)
        if result:
            seeds.append({
                'song': song,
                'artist': artist,
                'features': result['features'],
                'popularity': result['popularity'],
                'year': result['year']
            })
    
    df_seeds = pd.DataFrame(seeds)
    df_seeds[FEATURES] = pd.DataFrame(df_seeds['features'].tolist(), index=df_seeds.index)
    df_seeds = df_seeds.drop(columns=['features'])
    
    print("\n" + "="*50)
    print("SEED SUMMARY")
    print("="*50)
    print(df_seeds)
    
    return df_seeds

# Get song features
def get_song_features(df_playlist_metadata, df_playlist_features, song_name, artist_name=None):
    mask = df_playlist_metadata['Song'].str.contains(song_name, case=False, na=False)
    if artist_name:
        mask = mask & df_playlist_metadata['Artist'].str.contains(artist_name, case=False, na=False)
    
    if mask.sum() == 0:
        print(f"Couldn't find '{song_name}'" + (f" by '{artist_name}'" if artist_name else ""))
        return None
    
    idx = df_playlist_metadata[mask].index[0]
    meta = df_playlist_metadata.loc[idx]
    feats = df_playlist_features.loc[idx]
    
    print(f"{meta['Song']} — {meta['Artist']} ({meta['Album Year']})")
    print(f"  Popularity: {meta['Popularity']}")
    for feature in FEATURES:
        print(f"  {feature}: {feats[feature]}")
    
    return {
    'features': [int(feats[f]) for f in FEATURES],
    'popularity': int(meta['Popularity']),
    'year': int(meta['Album Year'])
    }

def visualize_seeds(df_playlist_features, df_seeds):
    # Scale full playlist
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(df_playlist_features)
    
    # PCA
    pca = PCA(n_components=3)
    X_pca = pca.fit_transform(X_scaled)
    var_explained = pca.explained_variance_ratio_
    
    # Find best k
    def get_best_k(X_scaled, k_range=(3, 11)):
        scores = {}
        for k in range(k_range[0], k_range[1]):
            km = KMeans(n_clusters=k, n_init=50, random_state=42)
            labels = km.fit_predict(X_scaled)
            scores[k] = silhouette_score(X_scaled, labels)
        best_k = max(scores, key=scores.get)
        return best_k, scores
    
    best_k, scores = get_best_k(X_scaled)
    
    # Cluster with best k
    kmeans = KMeans(n_clusters=best_k, random_state=42, n_init=10)
    clusters = kmeans.fit_predict(X_scaled)
    
    # Transform seeds
    seeds_scaled = scaler.transform(df_seeds[FEATURES])
    seeds_pca = pca.transform(seeds_scaled)
    
    # Calculate distance from each seed to its cluster center
    seed_clusters = kmeans.predict(seeds_scaled)
    seed_distances = []
    for idx, seed in enumerate(seeds_scaled):
        center = kmeans.cluster_centers_[seed_clusters[idx]]
        distance = np.linalg.norm(seed - center)
        seed_distances.append(distance)
    
    # Plot
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    pairs = [(0, 1), (0, 2), (1, 2)]
    labels = ['PC1', 'PC2', 'PC3']
    
    for ax, (i, j) in zip(axes, pairs):
        ax.scatter(X_pca[:, i], X_pca[:, j], c=clusters, cmap='viridis', alpha=0.5)
        ax.scatter(seeds_pca[:, i], seeds_pca[:, j], 
                   c='red', s=150, edgecolors='black', linewidths=2, label='Seeds', zorder=5)
        for idx, row in df_seeds.iterrows():
            ax.annotate(row['song'], (seeds_pca[idx, i], seeds_pca[idx, j]),
                        fontsize=8, ha='left', va='bottom')
        ax.set_xlabel(f'{labels[i]} ({var_explained[i]:.1%})')
        ax.set_ylabel(f'{labels[j]} ({var_explained[j]:.1%})')
    
    axes[0].legend()
    plt.suptitle(f'Seed Placement by Cluster (k={best_k})', fontsize=14)
    plt.tight_layout()
    plt.show()
    
    # Print results
    print(f"\nBest k: {best_k} (silhouette: {scores[best_k]:.3f})")
    print("\nSEED CLUSTER ASSIGNMENTS")
    print("="*50)
    for idx, row in df_seeds.iterrows():
        print(f"{row['song']} → Cluster {seed_clusters[idx]} (distance: {seed_distances[idx]:.2f})")
    
    return {
        'kmeans': kmeans,
        'scaler': scaler,
        'clusters': clusters,
        'best_k': best_k
    }

# %%
seed_songs_dict = {
    "Can't C Me": "2Pac",
    "Forgot About Dre": "Dr. Dre", 
    "Dance With Me": "112", 
    "Heated": "Beyoncé",
    "Tunnel Vision": "Justin Timberlake"
}

df_seeds = collect_seeds(df_playlist_metadata, df_playlist_features, seed_songs_dict)
result = visualize_seeds(df_playlist_features, df_seeds)
# Out:
# Can't C Me — 2Pac (1996)
#   Popularity: 70
#   BPM: 95
#   Dance: 80
#   Energy: 85
#   Valence: 67
#   Acoustic: 4
# Forgot About Dre — Dr. Dre,Eminem (1999)
#   Popularity: 80
#   BPM: 134
#   Dance: 92
#   Energy: 74
#   Valence: 62
#   Acoustic: 8
# Dance With Me — 112 (2001)
#   Popularity: 66
#   BPM: 102
#   Dance: 91
#   Energy: 51
#   Valence: 61
#   Acoustic: 3
# HEATED — Beyoncé (2022)
#   Popularity: 67
#   BPM: 111
#   Dance: 79
#   Energy: 73
#   Valence: 50
#   Acoustic: 6
# Tunnel Vision — Justin Timberlake (2013)
#   Popularity: 52
#   BPM: 142
#   Dance: 57
#   Energy: 77
#   Valence: 57
#   Acoustic: 28
#
# ==================================================
# SEED SUMMARY
# ==================================================
#                song             artist  popularity  year  BPM  Dance  Energy  \
# 0        Can't C Me               2Pac          70  1996   95     80      85
# 1  Forgot About Dre            Dr. Dre          80  1999  134     92      74
# 2     Dance With Me                112          66  2001  102     91      51
# 3            Heated            Beyoncé          67  2022  111     79      73
# 4     Tunnel Vision  Justin Timberlake          52  2013  142     57      77
#
#    Valence  Acoustic
# 0       67         4
# 1       62         8
# 2       61         3
# 3       50         6
# 4       57        28
# Best k: 3 (silhouette: 0.218)
#
# SEED CLUSTER ASSIGNMENTS
# ==================================================
# Can't C Me → Cluster 0 (distance: 1.14)
# Forgot About Dre → Cluster 0 (distance: 1.41)
# Dance With Me → Cluster 0 (distance: 1.87)
# Heated → Cluster 0 (distance: 0.93)
# Tunnel Vision → Cluster 1 (distance: 1.47)

# %% [markdown]
# ### 2. Select K-Nearest Neighbors for each song

# %%
## == HELPER FUNCTIONS ===

def find_similar_songs(df_playlist_metadata, df_playlist_features, target, n=10):
    """
    Find similar songs using KNN on audio features.
    
    Parameters:
    - target: list of feature values [BPM, Dance, Energy, Valence, Acoustic]
    - n: number of neighbors to return
    """
    # Scale features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(df_playlist_features)
    
    # Fit KNN
    knn = NearestNeighbors(n_neighbors=n, metric='euclidean')
    knn.fit(X_scaled)
    
    # Scale target and get neighbors
    target_df = pd.DataFrame([target], columns=FEATURES)
    target_scaled = scaler.transform(target_df)[0]
    distances, indices = knn.kneighbors([target_scaled])
    
    # Build results
    results = []
    for dist, idx in zip(distances[0], indices[0]):
        meta = df_playlist_metadata.iloc[idx]
        feats = df_playlist_features.iloc[idx]
        results.append({
            'song': meta['Song'],
            'artist': meta['Artist'],
            'year': meta['Album Year'],
            'popularity': meta['Popularity'],
            'distance': round(dist, 3),
            **{f: feats[f] for f in FEATURES}
        })
    
    df_neighbors = pd.DataFrame(results)
    
    # Print
    print(f"Target: {dict(zip(FEATURES, target))}\n")
    for _, row in df_neighbors.iterrows():
        print(f"{row['song']} — {row['artist']} ({row['year']}) | dist: {row['distance']}")
    
    return df_neighbors

def generate_playlist(df_playlist_metadata, df_playlist_features, df_seeds, n_per_seed=10):
    """
    Generate a playlist by finding KNN neighbors for each seed song.
    
    Parameters:
    - df_seeds: DataFrame from collect_seeds()
    - n_per_seed: neighbors per seed (10 = ~50 songs after deduping)
    
    Returns:
    - DataFrame of unique songs sorted by BPM, Valence, Dance
    """
    all_neighbors = []
    
    for _, seed in df_seeds.iterrows():
        target = [seed[f] for f in FEATURES]
        neighbors = find_similar_songs(df_playlist_metadata, df_playlist_features, target, n=n_per_seed)
        all_neighbors.append(neighbors)
        print()  # spacing between seeds
    
    # Combine and dedupe
    df_playlist = (
        pd.concat(all_neighbors)
        .drop_duplicates(subset=['song', 'artist'])
        .sort_values(['BPM', 'Valence', 'Dance'])
        .reset_index(drop=True)
    )
    
    # Summary
    print("=" * 50)
    print(f"GENERATED PLAYLIST (n={len(df_playlist)})")
    print("=" * 50)
    print(f"Mean: { {f: round(df_playlist[f].mean(), 2) for f in FEATURES} }")
    print(f"Std:  { {f: round(df_playlist[f].std(), 2) for f in FEATURES} }")
    
    return df_playlist

# %%
df_playlist = generate_playlist(df_playlist_metadata, df_playlist_features, df_seeds, n_per_seed=10)

# Save playlist
df_playlist.to_csv('results/knn_playlist.csv', index=False)
df_playlist
# Out:
# Target: {'BPM': 95, 'Dance': 80, 'Energy': 85, 'Valence': 67, 'Acoustic': 4}
#
# Can't C Me — 2Pac (1996) | dist: 0.0
# How Many Licks? (feat. Sisqo) — Lil' Kim,Sisqo (2000) | dist: 0.394
# It Makes Me Ill — *NSYNC (2000) | dist: 0.415
# Bootylicious — Destiny's Child (2001) | dist: 0.471
# SPIT IN MY FACE! — ThxSoMch (2022) | dist: 0.6
# Butterfly — Crazy Town (2000) | dist: 0.661
# Love Like — Kehlani (2024) | dist: 0.686
# Hey Baby — No Doubt,Bounty Killer (2001) | dist: 0.701
# Ms. Jackson — Outkast (2000) | dist: 0.72
# Queen of the Night - Radio Edit — Whitney Houston (1992) | dist: 0.761
#
# Target: {'BPM': 134, 'Dance': 92, 'Energy': 74, 'Valence': 62, 'Acoustic': 8}
#
# Forgot About Dre — Dr. Dre,Eminem (1999) | dist: 0.0
# Snap Backs & Tattoos — Driicky Graham (2012) | dist: 0.682
# Old Town Road (feat. Billy Ray Cyrus) - Remix — Lil Nas X,Billy Ray Cyrus (2019) | dist: 0.819
# Cold Hearted — Paula Abdul (1988) | dist: 0.857
# Don't Cha — The Pussycat Dolls,Busta Rhymes (2005) | dist: 0.955
# Get Up (feat. Chamillionaire) — Ciara,Chamillionaire (2006) | dist: 0.991
# Little Bit — Lykke Li (2008) | dist: 1.0
# Lose Control (feat. Ciara & Fat Man Scoop) — Missy Elliott,Ciara,Fatman Scoop (2005) | dist: 1.026
# Wild Thing — Tone-Loc (1989) | dist: 1.032
# Die Another Day — Madonna (2002) | dist: 1.034
#
# Target: {'BPM': 102, 'Dance': 91, 'Energy': 51, 'Valence': 61, 'Acoustic': 3}
#
# Dance With Me — 112 (2001) | dist: 0.0
# Paul Revere — Beastie Boys (1986) | dist: 0.498
# Fish Paste — Die Antwoord (2010) | dist: 0.514
# Figure It Out — Maroon 5 (2007) | dist: 0.707
# Talk To Me — Peaches (2009) | dist: 0.75
# It Wasn't Me — Shaggy,Rik Rok (2000) | dist: 0.815
# You're a Jerk — New Boyz (2009) | dist: 0.859
# Magic Stick — Lil' Kim (2003) | dist: 0.862
# It's Goin' Down (feat. Nitti) — Yung Joc,NITTI (2006) | dist: 0.883
# Touch It — Monifah (1998) | dist: 0.942
#
# Target: {'BPM': 111, 'Dance': 79, 'Energy': 73, 'Valence': 50, 'Acoustic': 6}
#
# HEATED — Beyoncé (2022) | dist: 0.0
# Shut Up — Black Eyed Peas (2003) | dist: 0.383
# Come Baby Come — K7 (1993) | dist: 0.418
# Die Another Day — Madonna (2002) | dist: 0.535
# Grit Your Teeth — Martin Luke Brown (2018) | dist: 0.558
# Everybody (Backstreet's Back) - Extended Version — Backstreet Boys (1996) | dist: 0.586
# Second Best — Younger Hunger (2019) | dist: 0.601
# Hollow Moon (Bad Wolf) — AWOLNATION (2015) | dist: 0.62
# Paparazzi — Lady Gaga (2008) | dist: 0.62
# Dream Walkin' — Toby Keith (1997) | dist: 0.626
#
# Target: {'BPM': 142, 'Dance': 57, 'Energy': 77, 'Valence': 57, 'Acoustic': 28}
#
# Tunnel Vision — Justin Timberlake (2013) | dist: 0.0
# Cowboy Gangster Politician — Goldie Boutilier (2022) | dist: 1.012
# The Con — Tegan and Sara (2007) | dist: 1.032
# Danger Zone - From  Top Gun  Original Soundtrack — Kenny Loggins (1997) | dist: 1.074
# No Room in Frame — Death Cab for Cutie (2015) | dist: 1.092
# Who Are You — The Who (1978) | dist: 1.102
# Like a Boy — Ciara (2006) | dist: 1.143
# She's A Lady — Tom Jones (1971) | dist: 1.203
# Sweet Nothing (feat. Florence Welch) — Calvin Harris,Florence Welch (2012) | dist: 1.207
# All The Right Moves — OneRepublic (2009) | dist: 1.217
#
# ==================================================
# GENERATED PLAYLIST (n=49)
# ==================================================
# Mean: {'BPM': np.float64(115.24), 'Dance': np.float64(78.41), 'Energy': np.float64(71.92), 'Valence': np.float64(59.69), 'Acoustic': np.float64(9.51)}
# Std:  {'BPM': np.float64(17.42), 'Dance': np.float64(11.81), 'Energy': np.float64(12.65), 'Valence': np.float64(9.98), 'Acoustic': np.float64(8.27)}
#                                                 song  \
# 0                      It's Goin' Down (feat. Nitti)
# 1                                        Paul Revere
# 2                                        Magic Stick
# 3                                   SPIT IN MY FACE!
# 4                                           Hey Baby
# 5                                        Ms. Jackson
# 6                                         Fish Paste
# 7                                       It Wasn't Me
# 8                                         Can't C Me
# 9                                          Love Like
# 10                                     You're a Jerk
# 11                                     Figure It Out
# 12                                     Dance With Me
# 13                                       Second Best
# 14                                      Bootylicious
# 15                                         Butterfly
# 16                     How Many Licks? (feat. Sisqo)
# 17                                   It Makes Me Ill
# 18                   Queen of the Night - Radio Edit
# 19                                    Come Baby Come
# 20  Everybody (Backstreet's Back) - Extended Version
# 21                                            HEATED
# 22                                           Shut Up
# 23                                         Paparazzi
# 24                                          Touch It
# 25                                     Dream Walkin'
# 26                                        Talk To Me
# 27                            Hollow Moon (Bad Wolf)
# 28                                         Don't Cha
# 29                                      She's A Lady
# 30                                        Little Bit
# 31                                   Grit Your Teeth
# 32                                      Cold Hearted
# 33                                   Die Another Day
# 34                                  No Room in Frame
# 35        Lose Control (feat. Ciara & Fat Man Scoop)
# 36                                        Wild Thing
# 37              Sweet Nothing (feat. Florence Welch)
# 38                     Get Up (feat. Chamillionaire)
# 39                        Cowboy Gangster Politician
# 40                                           The Con
# 41                                        Like a Boy
# 42                                  Forgot About Dre
# 43     Old Town Road (feat. Billy Ray Cyrus) - Remix
# 44                              Snap Backs & Tattoos
# 45                                     Tunnel Vision
# 46                               All The Right Moves
# 47                                       Who Are You
# 48  Danger Zone - From  Top Gun  Original Soundtrack
#
#                               artist  year  popularity  distance  BPM  Dance  \
# 0                     Yung Joc,NITTI  2006          70     0.883   84     89
# 1                       Beastie Boys  1986          61     0.498   92     88
# 2                           Lil' Kim  2003          63     0.862   93     85
# 3                           ThxSoMch  2022          79     0.600   94     73
# 4             No Doubt,Bounty Killer  2001          61     0.701   94     71
# 5                            Outkast  2000          84     0.720   95     84
# 6                       Die Antwoord  2010          38     0.514   95     87
# 7                     Shaggy,Rik Rok  2000          82     0.815   95     85
# 8                               2Pac  1996          70     0.000   95     80
# 9                            Kehlani  2024          40     0.686   97     78
# 10                          New Boyz  2009          53     0.859   99     93
# 11                          Maroon 5  2007          24     0.707  100     89
# 12                               112  2001          66     0.000  102     91
# 13                    Younger Hunger  2019          37     0.601  103     73
# 14                   Destiny's Child  2001          63     0.471  103     84
# 15                        Crazy Town  2000          79     0.661  104     74
# 16                    Lil' Kim,Sisqo  2000          57     0.394  105     78
# 17                            *NSYNC  2000          49     0.415  105     81
# 18                   Whitney Houston  1992          54     0.761  105     74
# 19                                K7  1993          64     0.418  106     83
# 20                   Backstreet Boys  1996          63     0.586  108     79
# 21                           Beyoncé  2022          67     0.000  111     79
# 22                   Black Eyed Peas  2003          73     0.383  113     81
# 23                         Lady Gaga  2008          76     0.620  115     76
# 24                           Monifah  1998          55     0.942  115     86
# 25                        Toby Keith  1997          56     0.626  117     71
# 26                           Peaches  2009          23     0.750  118     95
# 27                        AWOLNATION  2015          47     0.620  120     75
# 28   The Pussycat Dolls,Busta Rhymes  2005          70     0.955  120     88
# 29                         Tom Jones  1971          69     1.203  120     51
# 30                          Lykke Li  2008          68     1.000  120     82
# 31                 Martin Luke Brown  2018          24     0.558  122     81
# 32                       Paula Abdul  1988          55     0.857  122     88
# 33                           Madonna  2002          33     1.034  124     80
# 34               Death Cab for Cutie  2015          45     1.092  125     64
# 35  Missy Elliott,Ciara,Fatman Scoop  2005          70     1.026  125     90
# 36                          Tone-Loc  1989          65     1.032  126     94
# 37      Calvin Harris,Florence Welch  2012          77     1.207  128     57
# 38              Ciara,Chamillionaire  2006          66     0.991  129     96
# 39                  Goldie Boutilier  2022          70     1.012  130     67
# 40                    Tegan and Sara  2007          45     1.032  130     57
# 41                             Ciara  2006          67     1.143  132     70
# 42                    Dr. Dre,Eminem  1999          80     0.000  134     92
# 43         Lil Nas X,Billy Ray Cyrus  2019          78     0.819  136     88
# 44                    Driicky Graham  2012          43     0.682  140     86
# 45                 Justin Timberlake  2013          52     0.000  142     57
# 46                       OneRepublic  2009          69     1.217  146     53
# 47                           The Who  1978          62     1.102  156     65
# 48                     Kenny Loggins  1997          75     1.074  157     54
#
#     Energy  Valence  Acoustic
# 0       58       61        10
# 1       55       58         2
# 2       50       50        12
# 3       79       65         5
# 4       87       75         6
# 5       81       61        14
# 6       49       62         9
# 7       61       65         6
# 8       85       67         4
# 9       75       62         2
# 10      46       52        15
# 11      55       46         4
# 12      51       61         3
# 13      68       50         3
# 14      84       64         0
# 15      81       61         0
# 16      85       65         5
# 17      86       65         1
# 18      90       76         0
# 19      73       55         3
# 20      81       51         1
# 21      73       50         6
# 22      72       58         7
# 23      69       40        11
# 24      48       78         3
# 25      75       54         9
# 26      56       55         2
# 27      76       41         9
# 28      64       57         1
# 29      88       62        21
# 30      74       70        16
# 31      71       48        12
# 32      68       72        15
# 33      76       49         9
# 34      72       44        20
# 35      81       81         3
# 36      69       81         0
# 37      93       58        20
# 38      60       63         2
# 39      70       63        21
# 40      85       70        18
# 41      72       43        27
# 42      74       62         8
# 43      62       64         5
# 44      69       54        12
# 45      77       57        28
# 46      95       65        26
# 47      65       49        26
# 48      90       65        24
